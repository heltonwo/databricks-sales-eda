-- %%
 -- Bronze layer for raw ingestion data
CREATE SCHEMA IF NOT EXISTS sales_project_db.bronze;

-- Silver layer for cleaned and modeled dimensional data
CREATE SCHEMA IF NOT EXISTS sales_project_db.silver;
